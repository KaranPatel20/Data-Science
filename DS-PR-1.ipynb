# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
name=[] #List to store name of the series
ratings=[]
genre=[] 
year=[] 
url = "https://www.imdb.com/search/title/?title_type=tv_series&num_votes=100000,&sort=user_rating,desc"
content = requests.get(url).content

# %%
soup = BeautifulSoup(content,"html.parser")

for a in soup.findAll('div', attrs={'class':'lister-item mode-advanced'}):
    h = a.find('h3', attrs={'class':'lister-item-header'})
    a_name=h.find('a', href=True)
    a_rating=a.find('div', attrs={'class':'inline-block ratings-imdb-rating'})
    a_genre=a.find('span', attrs={'class':'genre'})
    a_year=a.find('span', attrs={'class':'lister-item-year text-muted unbold'})
    name.append(a_name.text)
    ratings.append(a_rating.text.strip("\n"))
    genre.append(a_genre.text.strip("\n"))
    year.append(a_year.text)

# %%
df=pd.DataFrame({'Series Title':name, 'Years':year, 'Rating':ratings, 'Genre':genre}) 
df.to_csv('DS-PR1-18IT089.csv', index=False, encoding="utf-8-sig")

# %%
df
# Out:
#                           Series Title        Years Rating  \
# 0                            Aspirants     (2021– )    9.7
# 1   Scam 1992: The Harshad Mehta Story       (2020)    9.5
# 2                         Breaking Bad  (2008–2013)    9.4
# 3           Avatar: The Last Airbender  (2005–2008)    9.3
# 4                             The Wire  (2002–2008)    9.3
# 5                       Rick and Morty     (2013– )    9.2
# 6                      Game of Thrones  (2011–2019)    9.2
# 7                         The Sopranos  (1999–2007)    9.2
# 8                             Sherlock  (2010–2017)    9.1
# 9             Hagane no renkinjutsushi  (2009–2012)    9.1
# 10                  Shingeki no kyojin  (2013–2022)    9.0
# 11               Death Note: Desu nôto  (2006–2007)    9.0
# 12                             Firefly  (2002–2003)    9.0
# 13                               Fargo     (2014– )    8.9
# 14                      True Detective  (2014–2019)    8.9
# 15                          The Office  (2005–2013)    8.9
# 16                             Friends  (1994–2004)    8.9
# 17                     The Mandalorian     (2019– )    8.8
# 18                                Dark  (2017–2020)    8.8
# 19            One Punch Man: Wanpanman     (2015– )    8.8
# 20                    Better Call Saul     (2015– )    8.8
# 21                              Narcos  (2015–2017)    8.8
# 22                      Peaky Blinders     (2013– )    8.8
# 23                        Black Mirror     (2011– )    8.8
# 24   It's Always Sunny in Philadelphia     (2005– )    8.8
# 25                          Twin Peaks  (1990–1991)    8.8
# 26                            Seinfeld  (1989–1998)    8.8
# 27                             Fleabag  (2016–2019)    8.7
# 28                          This Is Us  (2016–2022)    8.7
# 29                     Stranger Things     (2016– )    8.7
# 30                     BoJack Horseman  (2014–2020)    8.7
# 31                      House of Cards  (2013–2018)    8.7
# 32                       Downton Abbey  (2010–2015)    8.7
# 33                            The Boys     (2019– )    8.7
# 34                          House M.D.  (2004–2012)    8.7
# 35                Battlestar Galactica  (2004–2009)    8.7
# 36                                Rome  (2005–2007)    8.7
# 37                Arrested Development  (2003–2019)    8.7
# 38                Curb Your Enthusiasm     (2000– )    8.7
# 39                      Six Feet Under  (2001–2005)    8.7
# 40                       Dragon Ball Z  (1996–2003)    8.7
# 41                    Freaks and Geeks  (1999–2000)    8.7
# 42                          South Park     (1997– )    8.7
# 43                                Loki     (2021– )    8.6
# 44                           Cobra Kai     (2018– )    8.6
# 45                          Mindhunter  (2017–2019)    8.6
# 46                           The Crown     (2016– )    8.6
# 47                           Daredevil  (2015–2018)    8.6
# 48                        The Newsroom  (2012–2014)    8.6
# 49                            Top Gear     (2002– )    8.6
#
#                                         Genre
# 0                           Drama
# 1         Biography, Crime, Drama
# 2          Crime, Drama, Thriller
# 3    Animation, Action, Adventure
# 4          Crime, Drama, Thriller
# 5    Animation, Adventure, Comedy
# 6        Action, Adventure, Drama
# 7                    Crime, Drama
# 8           Crime, Drama, Mystery
# 9    Animation, Action, Adventure
# 10   Animation, Action, Adventure
# 11        Animation, Crime, Drama
# 12       Adventure, Drama, Sci-Fi
# 13         Crime, Drama, Thriller
# 14          Crime, Drama, Mystery
# 15                         Comedy
# 16                Comedy, Romance
# 17      Action, Adventure, Sci-Fi
# 18          Crime, Drama, Mystery
# 19      Animation, Action, Comedy
# 20                   Crime, Drama
# 21        Biography, Crime, Drama
# 22                   Crime, Drama
# 23        Drama, Sci-Fi, Thriller
# 24                         Comedy
# 25          Crime, Drama, Mystery
# 26                         Comedy
# 27                  Comedy, Drama
# 28         Comedy, Drama, Romance
# 29         Drama, Fantasy, Horror
# 30       Animation, Comedy, Drama
# 31                          Drama
# 32                 Drama, Romance
# 33           Action, Crime, Drama
# 34                 Drama, Mystery
# 35       Action, Adventure, Drama
# 36         Action, Drama, History
# 37                         Comedy
# 38                         Comedy
# 39                  Comedy, Drama
# 40   Animation, Action, Adventure
# 41                  Comedy, Drama
# 42              Animation, Comedy
# 43     Action, Adventure, Fantasy
# 44          Action, Comedy, Drama
# 45         Crime, Drama, Thriller
# 46      Biography, Drama, History
# 47           Action, Crime, Drama
# 48                          Drama
# 49  Adventure, Comedy, Reality-TV
